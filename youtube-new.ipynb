# %%
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter

# %%
table = pd.read_csv(r'CAvideos.csv')
print(table)
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %% [markdown]
# # 标称属性

# %%
NominalAttribute = ['trending_date', 'publish_time', 'category_id','comments_disabled','ratings_disabled','video_error_or_removed']

# %% [markdown]
# 输出各个属性的频数

# %%
for i in NominalAttribute:
    attrValue = []
    for j in table[i]:
        if j==j:
            attrValue.append(j)
    count = Counter(attrValue)
    count_dict = dict(count)
    print('{}的频数：'.format(i))
    print(count_dict)
# Out:
# trending_date的频数：
# ...

# %% [markdown]
# # 数值属性
# 1. views

# %%
#views的五数概括
views_r = []
views = []
for i in table['views']:
    views_r.append(i)
    if i == i:
        views.append(i)
miss = 0
print('最大值：', max(views))
print('最小值：', min(views))
print('中位数：', np.median(views))
print('四分位数：', np.percentile(views, (25, 50, 75), interpolation='midpoint'))
for i in views_r:
    if i != i:
        miss += 1
print('缺失值个数：', miss)
# Out:
# 最大值： 137843120
# 最小值： 733
# 中位数： 371204.0
# 四分位数： [143902. 371204. 963302.]
# 缺失值个数： 0

# %%
#views的直方图
plt.hist(views_r, 2000)
plt.xlabel('views')
plt.ylabel('number')
plt.xlim(min(views), 3000000)
plt.ylim(0.0, 5000)
plt.title('views')
plt.show()

# %%
#views盒图
data = pd.DataFrame({'views': views})
data.boxplot()
plt.ylabel('views')
plt.xlabel('')
plt.show()

# %% [markdown]
# 2. likes

# %%
#likes的五数概括
likes_r = []
likes = []
for i in table['likes']:
    likes_r.append(i)
    if i == i:
        likes.append(i)
miss = 0
print('最大值：', max(likes))
print('最小值：', min(likes))
print('中位数：', np.median(likes))
print('四分位数：', np.percentile(likes, (25, 50, 75), interpolation='midpoint'))
for i in likes_r:
    if i != i:
        miss += 1
print('缺失值个数：', miss)
# Out:
# 最大值： 5053338
# 最小值： 0
# 中位数： 8780.0
# 四分位数： [ 2191.  8780. 28717.]
# 缺失值个数： 0

# %%
#likes直方图
plt.hist(likes_r, 2000)
plt.xlabel('likes')
plt.ylabel('number')
plt.xlim(min(likes), 500000)
plt.ylim(0.0, 6000)
plt.title('likes')
plt.show()

# %%
#likes盒图
data = pd.DataFrame({'likes': likes})
data.boxplot()
plt.ylabel('likes')
plt.xlabel('')
plt.show()

# %% [markdown]
# 3. dislikes

# %%
#dislikes的五数概括
dislikes_r = []
dislikes = []
for i in table['dislikes']:
    dislikes_r.append(i)
    if i == i:
        dislikes.append(i)
miss = 0
print('最大值：', max(dislikes))
print('最小值：', min(dislikes))
print('中位数：', np.median(dislikes))
print('四分位数：', np.percentile(dislikes, (25, 50, 75), interpolation='midpoint'))
for i in dislikes_r:
    if i != i:
        miss += 1
print('缺失值个数：', miss)
# Out:
# 最大值： 1602383
# 最小值： 0
# 中位数： 303.0
# 四分位数： [ 99. 303. 950.]
# 缺失值个数： 0

# %%
#dislikes直方图
plt.hist(dislikes_r, 2000)
plt.xlabel('dislikes')
plt.ylabel('number')
plt.xlim(min(dislikes), 50000)
plt.ylim(0.0, 30000)
plt.title('dislikes')
plt.show()

# %%
#dislikes盒图
data = pd.DataFrame({'dislikes': dislikes})
data.boxplot()
plt.ylabel('dislikes')
plt.xlabel('')
plt.show()

# %% [markdown]
# 4. comment_count

# %%
#comment_count五数概括
comment_count_r = []
comment_count = []
for i in table['comment_count']:
    comment_count_r.append(i)
    if i == i:
        comment_count.append(i)
miss = 0
print('最大值：', max(comment_count))
print('最小值：', min(comment_count))
print('中位数：', np.median(comment_count))
print('四分位数：', np.percentile(comment_count, (25, 50, 75), interpolation='midpoint'))
for i in comment_count_r:
    if i != i:
        miss += 1
print('缺失值个数：', miss)
# Out:
# 最大值： 1114800
# 最小值： 0
# 中位数： 1301.0
# 四分位数： [ 417. 1301. 3713.]
# 缺失值个数： 0

# %%
#comment_count直方图
plt.hist(comment_count_r, 2000)
plt.xlabel('comment_count')
plt.ylabel('number')
plt.xlim(min(comment_count), 20000)
plt.ylim(0.0, 15000)
plt.title('comment_count')
plt.show()

# %%
#comment_count盒图
data = pd.DataFrame({'comment_count': comment_count})
data.boxplot()
plt.ylabel('comment_count')
plt.xlabel('')
plt.show()

# %% [markdown]
# # 缺失数据处理（此数据集无缺失数据）
